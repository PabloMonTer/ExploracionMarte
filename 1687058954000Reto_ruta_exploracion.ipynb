# %% [markdown]
# # **Planeación de rutas para la exploración en Marte**
#
# Yuu Ricardo Akachi Tanaka | A01351969
#
# Pablo Monzón Terrazas | A01562619
#
# Donnet Emmanuel Hernández Franco | A01352049

# %%
# ejecutar si no se tiene instalado simpleai
# !pip install simpleai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpleai in /usr/local/lib/python3.10/dist-packages (0.8.3)

# %%
#---------------------------------------------------------------------------------------------------------------
#    PSA del robot explorador de Marte
#---------------------------------------------------------------------------------------------------------------

from simpleai.search import SearchProblem, depth_first, breadth_first, uniform_cost, greedy, astar
from simpleai.search.viewers import BaseViewer, ConsoleViewer, WebViewer
import numpy as np

#---------------------------------------------------------------------------------------------------------------
#   Definición del problema
#---------------------------------------------------------------------------------------------------------------

class Marte(SearchProblem):

    """
        Clase que es usada para definir el problema del robot explorador de Marte. Cada estado se representa
        por una coordenada.
    """

    def __init__(self):

        self.mapa = np.load('/content/mars_map.npy') # se crea el mapa de Marte
        self.nr, self.nc = self.mapa.shape # # se saca el tamaño del mapa
        self.x=2850 # x inicial
        self.y=6400 # y inicial
        self.r=self.nr-round(self.y/10.0174) # row escalado
        self.c=round(self.x/10.0174) # column escalado
        self.dif=0.25 # altura que puede bajar o subir

        initial_state = (self.r,self.c) # Estado (coordenada) en el que comienza el robot


        # Llama al constructor de su superclase SearchProblem.
        SearchProblem.__init__(self, initial_state)

        # Define el estado meta = que el robot termine en las coordenadas (3150,6800) ya escalado como en el mapa
        self.goal_state = (self.nr-round(6800/10.0174),round(3150/10.0174))

    def actions(self, state):
        """
            Este método regresa una lista con las acciones posibles que pueden ser ejecutadas de
            acuerdo con el estado especificado.

            state: todas las coordenadas del mapa

            state[0] = row
            state[1] = column
        """

        acciones=[]
        #Movimiento hacia delante (respecto a la matriz)
        if self.mapa[state[0]][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]+1])<self.dif:
          a1=[state[0],state[1]+1]
          acciones.append(a1)
        #Movimiento hacia atras (respecto a la matriz)
        if self.mapa[state[0]][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]-1])<self.dif:
          a2=[state[0],state[1]-1]
          acciones.append(a2)
        #Movimiento hacia la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]])<self.dif:
          a3=[state[0]+1,state[1]]
          acciones.append(a3)
        #Movimiento hacia la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]])<self.dif:
          a4=[state[0]-1,state[1]]
          acciones.append(a4)
        #Movimiento en diagonal hacia delante y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]+1])<self.dif:
          a5=[state[0]+1,state[1]+1]
          acciones.append(a5)
        #Movimiento en diagonal hacia delante y la izquierda
        if self.mapa[state[0]-1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]+1])<self.dif:
          a6=[state[0]-1,state[1]+1]
          acciones.append(a6)
        #Movimiento en diagonal hacia atras y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]-1])<self.dif:
          a7=[state[0]+1,state[1]-1]
          acciones.append(a7)
        #Movimiento en diagonal hacia atras y la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]-1])<self.dif:
          a8=[state[0]-1,state[1]-1]
          acciones.append(a8)


        return acciones

    def result(self, state, action):
        """
            Este método regresa el nuevo estado obtenido despues de ejecutar la acción.

            state: el estado (coordenada) que se va a modificar
            action: movimiento que se hará en state (estado/coordenada)
        """
        return tuple([action[0],action[1]])

    def is_goal(self, state):
        """
            This method evaluates whether the specified state is the goal state.

            state: The state to be tested.
        """
        return state == self.goal_state

    def cost(self, state, action, state2):
        """
            Este método recibe dos estados y una acción, y regresa el costo de
            aplicar la acción del primer estado al segundo.

            state: Primer estado
            action: Acción usada para generar el segundo estado
            state2: Estado obtenido después de la acción
        """
        if abs(state2[0]-state[0]) == 1 and abs(state2[1]-state[1]) == 1:
          #moverse cada vez en diagonal tiene costo de 14.16
          return 14.16
        else:
          # moverse de otra forma tiene costo de 10.174
          return 10.0174


    def heuristic(self, state):
        """
            Este método regresa un estimado de la distancia desde el estado a la meta.

            state: Estado a ser evaluado

            La heurística es la distancia que le queda de llegar de donde está a la meta
        """
        distancia_diagonal=np.sqrt(((state[0]-self.goal_state[0])**2)+((state[1]-self.goal_state[1])**2))

        return distancia_diagonal


# Despliega los resultados
def display(result):
    if result is not None:
        for i, (action, state) in enumerate(result.path()):
            if action == None:
                print('Configuración inicial')
            elif i == len(result.path()) - 1:
                print(i,'- Después de moverse hacia', action)
                print('¡Meta lograda con costo =', result.cost,'!')
            else:
                print(i,'- Después de moverse hacia', action)

            for i in state:
              print('  ', i)
    else:
        print('No se puede resolver')

#---------------------------------------------------------------------------------------------------------------
#   Fin del archivo
#---------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------
#   Programa
#---------------------------------------------------------------------------------------------------------------

#my_viewer = None
my_viewer = BaseViewer()       # Solo estadísticas
#my_viewer = ConsoleViewer()    # Texto en la consola
#my_viewer = WebViewer()        # Abrir en un browser en la liga http://localhost:8000




# Crea un PSA y lo resuelve con la búsqueda primero en anchura
result = astar(Marte(), graph_search=True, viewer=my_viewer)
print()
print('>> Ruta hacia el punto destino')
display(result)
if my_viewer!=None:
    print('Stats:')
    print(my_viewer.stats)
print('\n\n')
# Out:
# >> Ruta hacia el punto destino
# Configuración inicial
#    1176
#    285
# 1 - Después de moverse hacia [1175, 285]
#    1175
#    285
# 2 - Después de moverse hacia [1174, 285]
#    1174
#    285
# 3 - Después de moverse hacia [1173, 285]
#    1173
#    285
# 4 - Después de moverse hacia [1172, 285]
#    1172
#    285
# 5 - Después de moverse hacia [1171, 285]
#    1171
#    285
# 6 - Después de moverse hacia [1170, 284]
#    1170
#    284
# 7 - Después de moverse hacia [1169, 284]
#    1169
#    284
# 8 - Después de moverse hacia [1168, 284]
#    1168
#    284
# 9 - Después de moverse hacia [1167, 284]
#    1167
#    284
# 10 - Después de moverse hacia [1166, 284]
#    1166
#    284
# 11 - Después de moverse hacia [1165, 283]
#    1165
#    283
# 12 - Después de moverse hacia [1164, 283]
#    1164
#    283
# 13 - Después de moverse hacia [1163, 283]
#    1163
#    283
# 14 - Después de moverse hacia [1162, 283]
#    1162
#    283
# 15 - Después de moverse hacia [1161, 283]
#    1161
#    283
# 16 - Después de moverse hacia [1160, 283]
#    1160
#    283
# 17 - Después de moverse hacia [1159, 283]
#    1159
#    283
# 18 - Después de moverse hacia [1158, 283]
# 267 - Después de moverse hacia [1094, 302]
#    1094
#    302
# 268 - Después de moverse hacia [1095, 302]
#    1095
#    302
# 269 - Después de moverse hacia [1096, 302]
#    1096
#    302
# 270 - Después de moverse hacia [1097, 302]
#    1097
#    302
# 271 - Después de moverse hacia [1098, 302]
#    1098
#    302
# 272 - Después de moverse hacia [1099, 302]
#    1099
#    302
# 273 - Después de moverse hacia [1100, 303]
#    1100
#    303
# 274 - Después de moverse hacia [1101, 304]
#    1101
#    304
# 275 - Después de moverse hacia [1102, 305]
#    1102
#    305
# 276 - Después de moverse hacia [1103, 305]
#    1103
#    305
# 277 - Después de moverse hacia [1104, 306]
#    1104
#    306
# 278 - Después de moverse hacia [1105, 307]
#    1105
#    307
# 279 - Después de moverse hacia [1106, 308]
#    1106
#    308
# 280 - Después de moverse hacia [1107, 308]
#    1107
#    308
# 281 - Después de moverse hacia [1108, 308]
#    1108
#    308
# 282 - Después de moverse hacia [1109, 308]
#    1109
#    308
# 283 - Después de moverse hacia [1110, 308]
#    1110
#    308
# 284 - Después de moverse hacia [1111, 308]
#    1111
#    308
# 285 - Después de moverse hacia [1112, 308]
#    1112
#    308
# 286 - Después de moverse hacia [1113, 308]
#    1113
#    308
# 287 - Después de moverse hacia [1114, 309]
#    1114
#    309
# 288 - Después de moverse hacia [1115, 310]
#    1115
#    310
# 289 - Después de moverse hacia [1116, 310]
#    1116
#    310
# 290 - Después de moverse hacia [1117, 311]
#    1117
#    311
# 291 - Después de moverse hacia [1118, 311]
#    1118
#    311
# 292 - Después de moverse hacia [1119, 311]
#    1119
#    311
# 293 - Después de moverse hacia [1120, 311]
#    1120
#    311
# 294 - Después de moverse hacia [1121, 311]
#    1121
#    311
# 295 - Después de moverse hacia [1122, 312]
#    1122
#    312
# 296 - Después de moverse hacia [1123, 313]
#    1123
#    313
# 297 - Después de moverse hacia [1124, 313]
#    1124
#    313
# 298 - Después de moverse hacia [1125, 313]
#    1125
#    313
# 299 - Después de moverse hacia [1126, 313]
#    1126
#    313
# 300 - Después de moverse hacia [1127, 313]
#    1127
#    313
# 301 - Después de moverse hacia [1128, 313]
#    1128
#    313
# 302 - Después de moverse hacia [1129, 313]
#    1129
#    313
# 303 - Después de moverse hacia [1130, 314]
#    1130
#    314
# 304 - Después de moverse hacia [1131, 314]
#    1131
#    314
# 305 - Después de moverse hacia [1132, 314]
#    1132
#    314
# 306 - Después de moverse hacia [1133, 314]
#    1133
#    314
# 307 - Después de moverse hacia [1134, 314]
#    1134
#    314
# 308 - Después de moverse hacia [1135, 314]
#    1135
#    314
# 309 - Después de moverse hacia [1136, 314]
# ¡Meta lograda con costo = 3385.3586000000105 !
#    1136
#    314
# Stats:
# {'max_fringe_size': 266, 'visited_nodes': 25377, 'iterations': 25377}

# %%
# Crea un PSA y lo resuelve con la búsqueda primero en anchura
result = breadth_first(Marte(), graph_search=True, viewer=my_viewer)
print()
print('>> Ruta hacia el punto destino')
display(result)
if my_viewer!=None:
    print('Stats:')
    print(my_viewer.stats)
print('\n\n')
# Out:
#    1126
#    313
# 299 - Después de moverse hacia [1127, 313]
#    1127
#    313
# 300 - Después de moverse hacia [1128, 313]
#    1128
#    313
# 301 - Después de moverse hacia [1129, 313]
#    1129
#    313
# 302 - Después de moverse hacia [1130, 314]
#    1130
#    314
# 303 - Después de moverse hacia [1131, 314]
#    1131
#    314
# 304 - Después de moverse hacia [1132, 314]
#    1132
#    314
# 305 - Después de moverse hacia [1133, 314]
#    1133
#    314
# 306 - Después de moverse hacia [1134, 314]
#    1134
#    314
# 307 - Después de moverse hacia [1135, 314]
#    1135
#    314
# 308 - Después de moverse hacia [1136, 314]
# ¡Meta lograda con costo = 3420.909800000011 !
#    1136
#    314
# Stats:
# {'max_fringe_size': 266, 'visited_nodes': 55024, 'iterations': 55024}

# %%
# Crea un PSA y lo resuelve con la búsqueda primero en anchura
result = depth_first(Marte(), graph_search=True, viewer=my_viewer)
print()
print('>> Ruta hacia el punto destino')
display(result)
if my_viewer!=None:
    print('Stats:')
    print(my_viewer.stats)
print('\n\n')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-0fa67f348a14> in <cell line: 2>()
#       1 # Crea un PSA y lo resuelve con la búsqueda primero en anchura
# ----> 2 result = depth_first(Marte(), graph_search=True, viewer=my_viewer)
#       3 print()
#       4 print('>> Ruta hacia el punto destino')
#       5 display(result)
#
# /usr/local/lib/python3.10/dist-packages/simpleai/search/traditional.py in depth_first(problem, graph_search, viewer)
#      28     SearchProblem.is_goal.
#      29     '''
# ---> 30     return _search(problem,
#      31                    LifoList(),
#      32                    graph_search=graph_search,
#
# /usr/local/lib/python3.10/dist-packages/simpleai/search/traditional.py in _search(problem, fringe, graph_search, depth_limit, node_factory, graph_replace_when_better, viewer)
#     160             for n in expanded:
#     161                 if graph_search:
# --> 162                     others = [x for x in fringe if x.state == n.state]
#     163                     assert len(others) in (0, 1)
#     164                     if n.state not in memory and len(others) == 0:
#
# /usr/local/lib/python3.10/dist-packages/simpleai/search/traditional.py in <listcomp>(.0)
#     160             for n in expanded:
#     161                 if graph_search:
# --> 162                     others = [x for x in fringe if x.state == n.state]
#     163                     assert len(others) in (0, 1)
#     164                     if n.state not in memory and len(others) == 0:
#
# KeyboardInterrupt:

# %%
# Crea un PSA y lo resuelve con la búsqueda primero en anchura
result = greedy(Marte(), graph_search=True, viewer=my_viewer)
print()
print('>> Ruta hacia el punto destino')
display(result)
if my_viewer!=None:
    print('Stats:')
    print(my_viewer.stats)
print('\n\n')
# Out:
# >> Ruta hacia el punto destino
# Configuración inicial
#    1176
#    285
# 1 - Después de moverse hacia [1175, 286]
#    1175
#    286
# 2 - Después de moverse hacia [1174, 287]
#    1174
#    287
# 3 - Después de moverse hacia [1173, 287]
#    1173
#    287
# 4 - Después de moverse hacia [1172, 286]
#    1172
#    286
# 5 - Después de moverse hacia [1171, 286]
#    1171
#    286
# 6 - Después de moverse hacia [1171, 287]
#    1171
#    287
# 7 - Después de moverse hacia [1170, 287]
#    1170
#    287
# 8 - Después de moverse hacia [1169, 287]
#    1169
#    287
# 9 - Después de moverse hacia [1168, 286]
#    1168
#    1025
#    288
# 259 - Después de moverse hacia [1026, 288]
#    1026
#    288
# 260 - Después de moverse hacia [1027, 289]
#    1027
#    289
# 261 - Después de moverse hacia [1028, 289]
#    1028
#    289
# 262 - Después de moverse hacia [1029, 289]
#    1029
#    289
# 263 - Después de moverse hacia [1030, 290]
#    1030
#    290
# 264 - Después de moverse hacia [1031, 291]
#    1031
#    291
# 265 - Después de moverse hacia [1032, 290]
#    1032
#    290
# 266 - Después de moverse hacia [1033, 291]
#    1033
#    291
# 267 - Después de moverse hacia [1034, 292]
#    1034
#    292
# 268 - Después de moverse hacia [1035, 293]
#    1035
#    293
# 269 - Después de moverse hacia [1036, 293]
#    1036
#    293
# 270 - Después de moverse hacia [1037, 293]
#    1037
#    293
# 271 - Después de moverse hacia [1038, 294]
#    1038
#    294
# 272 - Después de moverse hacia [1039, 295]
#    1039
#    295
# 273 - Después de moverse hacia [1040, 295]
#    1040
#    295
# 274 - Después de moverse hacia [1041, 296]
#    1041
#    296
# 275 - Después de moverse hacia [1042, 297]
#    1042
#    297
# 276 - Después de moverse hacia [1043, 297]
#    1043
#    297
# 277 - Después de moverse hacia [1044, 297]
#    1044
#    297
# 278 - Después de moverse hacia [1045, 298]
#    1045
#    298
# 279 - Después de moverse hacia [1046, 298]
#    1046
#    298
# 280 - Después de moverse hacia [1047, 298]
#    1047
#    298
# 281 - Después de moverse hacia [1048, 299]
#    1048
#    299
# 282 - Después de moverse hacia [1049, 299]
#    1049
#    299
# 283 - Después de moverse hacia [1050, 300]
#    1050
#    300
# 284 - Después de moverse hacia [1051, 300]
#    1051
#    300
# 285 - Después de moverse hacia [1052, 301]
#    1052
#    301
# 286 - Después de moverse hacia [1053, 301]
#    1053
#    301
# 287 - Después de moverse hacia [1054, 302]
#    1054
#    302
# 288 - Después de moverse hacia [1055, 302]
#    1055
#    302
# 289 - Después de moverse hacia [1056, 302]
#    1056
#    302
# 290 - Después de moverse hacia [1057, 302]
#    1057
#    302
# 291 - Después de moverse hacia [1058, 303]
#    1058
#    303
# 292 - Después de moverse hacia [1059, 304]
#    1059
#    304
# 293 - Después de moverse hacia [1060, 305]
#    1060
#    305
# 294 - Después de moverse hacia [1061, 306]
#    1061
#    306
# 295 - Después de moverse hacia [1062, 307]
#    1062
#    307
# 296 - Después de moverse hacia [1063, 308]
#    1063
#    308
# 297 - Después de moverse hacia [1064, 309]
#    1064
#    309
# 298 - Después de moverse hacia [1065, 309]
#    1065
#    309
# 299 - Después de moverse hacia [1066, 309]
#    1066
#    309
# 300 - Después de moverse hacia [1067, 310]
#    1067
#    310
# 301 - Después de moverse hacia [1068, 311]
#    1068
#    311
# 302 - Después de moverse hacia [1069, 312]
#    1069
#    312
# 303 - Después de moverse hacia [1070, 313]
#    1070
#    313
# 304 - Después de moverse hacia [1071, 313]
#    1071
#    313
# 305 - Después de moverse hacia [1072, 313]
#    1072
#    313
# 306 - Después de moverse hacia [1073, 313]
#    1073
#    313
# 307 - Después de moverse hacia [1074, 313]
#    1074
#    313
# 358 - Después de moverse hacia [1125, 317]
#    1125
#    317
# 359 - Después de moverse hacia [1126, 317]
#    1126
#    317
# 360 - Después de moverse hacia [1127, 317]
#    1127
#    317
# 361 - Después de moverse hacia [1128, 317]
#    1128
#    317
# 362 - Después de moverse hacia [1129, 317]
#    1129
#    317
# 363 - Después de moverse hacia [1130, 317]
#    1130
#    317
# 364 - Después de moverse hacia [1131, 317]
#    1131
#    317
# 365 - Después de moverse hacia [1132, 316]
#    1132
#    316
# 366 - Después de moverse hacia [1133, 316]
#    1133
#    316
# 367 - Después de moverse hacia [1134, 316]
#    1134
#    316
# 368 - Después de moverse hacia [1135, 315]
#    1135
#    315
# 369 - Después de moverse hacia [1136, 315]
#    1136
#    315
# 370 - Después de moverse hacia [1137, 315]
#    1137
#    315
# 371 - Después de moverse hacia [1138, 315]
#    1138
#    315
# 372 - Después de moverse hacia [1139, 316]
#    1139
#    316
# 373 - Después de moverse hacia [1139, 315]
#    1139
#    315
# 374 - Después de moverse hacia [1138, 314]
#    1138
#    314
# 375 - Después de moverse hacia [1137, 314]
#    1137
#    314
# 376 - Después de moverse hacia [1136, 314]
# ¡Meta lograda con costo = 4350.649000000005 !
#    1136
#    314
# Stats:
# {'max_fringe_size': 2035, 'visited_nodes': 63381, 'iterations': 63381}

# %% [markdown]
# # Ruta corta

# %%
#---------------------------------------------------------------------------------------------------------------
#    PSA del robot explorador de Marte
#---------------------------------------------------------------------------------------------------------------

from simpleai.search import SearchProblem, depth_first, breadth_first, uniform_cost, greedy, astar
from simpleai.search.viewers import BaseViewer, ConsoleViewer, WebViewer
import numpy as np

#---------------------------------------------------------------------------------------------------------------
#   Definición del problema
#---------------------------------------------------------------------------------------------------------------

class Marte(SearchProblem):

    """
        Clase que es usada para definir el problema del robot explorador de Marte. Cada estado se representa
        por una coordenada.
    """

    def __init__(self):

        self.mapa = np.load('/content/mars_map.npy') # se crea el mapa de Marte
        self.nr, self.nc = self.mapa.shape # # se saca el tamaño del mapa
        self.x=4000 # x inicial
        self.y=17000 # y inicial
        self.r=self.nr-round(self.y/10.0174) # row escalado
        self.c=round(self.x/10.0174) # column escalado
        self.dif=0.25 # altura que puede bajar o subir

        initial_state = (self.r,self.c) # Estado (coordenada) en el que comienza el robot


        # Llama al constructor de su superclase SearchProblem.
        SearchProblem.__init__(self, initial_state)

        # Define el estado meta = que el robot termine en las coordenadas (2400, 16000) ya escalado como en el mapa
        self.goal_state = (self.nr-round(17100/10.0174),round(4400/10.0174))

    def actions(self, state):
        """
            Este método regresa una lista con las acciones posibles que pueden ser ejecutadas de
            acuerdo con el estado especificado.

            state: todas las coordenadas del mapa

            state[0] = row
            state[1] = column
        """

        acciones=[]
        #Movimiento hacia delante (respecto a la matriz)
        if self.mapa[state[0]][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]+1])<self.dif:
          a1=[state[0],state[1]+1]
          acciones.append(a1)
        #Movimiento hacia atras (respecto a la matriz)
        if self.mapa[state[0]][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]-1])<self.dif:
          a2=[state[0],state[1]-1]
          acciones.append(a2)
        #Movimiento hacia la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]])<self.dif:
          a3=[state[0]+1,state[1]]
          acciones.append(a3)
        #Movimiento hacia la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]])<self.dif:
          a4=[state[0]-1,state[1]]
          acciones.append(a4)
        #Movimiento en diagonal hacia delante y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]+1])<self.dif:
          a5=[state[0]+1,state[1]+1]
          acciones.append(a5)
        #Movimiento en diagonal hacia delante y la izquierda
        if self.mapa[state[0]-1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]+1])<self.dif:
          a6=[state[0]-1,state[1]+1]
          acciones.append(a6)
        #Movimiento en diagonal hacia atras y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]-1])<self.dif:
          a7=[state[0]+1,state[1]-1]
          acciones.append(a7)
        #Movimiento en diagonal hacia atras y la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]-1])<self.dif:
          a8=[state[0]-1,state[1]-1]
          acciones.append(a8)


        return acciones

    def result(self, state, action):
        """
            Este método regresa el nuevo estado obtenido despues de ejecutar la acción.

            state: el estado (coordenada) que se va a modificar
            action: movimiento que se hará en state (estado/coordenada)
        """
        return tuple([action[0],action[1]])

    def is_goal(self, state):
        """
            This method evaluates whether the specified state is the goal state.

            state: The state to be tested.
        """
        return state == self.goal_state

    def cost(self, state, action, state2):
        """
            Este método recibe dos estados y una acción, y regresa el costo de
            aplicar la acción del primer estado al segundo.

            state: Primer estado
            action: Acción usada para generar el segundo estado
            state2: Estado obtenido después de la acción
        """
        if abs(state2[0]-state[0]) == 1 and abs(state2[1]-state[1]) == 1:
          #moverse cada vez en diagonal tiene costo de 14.16
          return 14.16
        else:
          # moverse de otra forma tiene costo de 10.174
          return 10.0174


    def heuristic(self, state):
        """
            Este método regresa un estimado de la distancia desde el estado a la meta.

            state: Estado a ser evaluado

            La heurística es la distancia que le queda de llegar de donde está a la meta
        """
        distancia_diagonal=np.sqrt(((state[0]-self.goal_state[0])**2)+((state[1]-self.goal_state[1])**2))

        return distancia_diagonal


# Despliega los resultados
def display(result):
    if result is not None:
        for i, (action, state) in enumerate(result.path()):
            if action == None:
                print('Configuración inicial')
            elif i == len(result.path()) - 1:
                print(i,'- Después de moverse hacia', action)
                print('¡Meta lograda con costo =', result.cost,'!')
            else:
                print(i,'- Después de moverse hacia', action)

            for i in state:
              print('  ', i)
    else:
        print('No se puede resolver')

#---------------------------------------------------------------------------------------------------------------
#   Fin del archivo
#---------------------------------------------------------------------------------------------------------------

# %%
# Crea un PSA y lo resuelve con la búsqueda a*
result = astar(Marte(), graph_search=True, viewer=my_viewer)
print()
print('>> Ruta hacia el punto destino')
display(result)
if my_viewer!=None:
    print('Stats:')
    print(my_viewer.stats)
print('\n\n')
# Out:
# >> Ruta hacia el punto destino
# Configuración inicial
#    118
#    399
# 1 - Después de moverse hacia [118, 400]
#    118
#    400
# 2 - Después de moverse hacia [118, 401]
#    118
#    401
# 3 - Después de moverse hacia [119, 402]
#    119
#    402
# 4 - Después de moverse hacia [120, 402]
#    120
#    402
# 5 - Después de moverse hacia [121, 402]
#    121
#    402
# 6 - Después de moverse hacia [122, 402]
#    122
#    402
# 7 - Después de moverse hacia [123, 403]
#    123
#    403
# 8 - Después de moverse hacia [123, 404]
#    123
#    404
# 9 - Después de moverse hacia [123, 405]
#    123
#    405
# 10 - Después de moverse hacia [122, 406]
#    122
#    406
# 11 - Después de moverse hacia [122, 407]
#    122
#    407
# 12 - Después de moverse hacia [122, 408]
#    122
#    408
# 13 - Después de moverse hacia [122, 409]
#    122
#    409
# 14 - Después de moverse hacia [121, 410]
#    121
#    410
# 15 - Después de moverse hacia [122, 410]
#    122
#    410
# 16 - Después de moverse hacia [123, 411]
#    123
#    411
# 17 - Después de moverse hacia [123, 412]
#    123
#    412
# 18 - Después de moverse hacia [124, 413]
#    124
#    413
# 19 - Después de moverse hacia [124, 414]
#    124
#    414
# 20 - Después de moverse hacia [124, 415]
#    124
#    415
# 21 - Después de moverse hacia [123, 416]
#    123
#    416
# 22 - Después de moverse hacia [124, 417]
#    124
#    417
# 23 - Después de moverse hacia [124, 418]
#    124
#    418
# 24 - Después de moverse hacia [124, 419]
#    124
#    419
# 25 - Después de moverse hacia [125, 419]
#    125
#    419
# 26 - Después de moverse hacia [124, 420]
#    124
#    420
# 27 - Después de moverse hacia [124, 421]
#    124
#    421
# 28 - Después de moverse hacia [125, 422]
#    125
#    422
# 29 - Después de moverse hacia [126, 423]
#    126
#    423
# 30 - Después de moverse hacia [126, 424]
#    126
#    424
# 31 - Después de moverse hacia [126, 425]
#    126
#    425
# 32 - Después de moverse hacia [126, 426]
#    126
#    426
# 33 - Después de moverse hacia [126, 427]
#    126
#    427
# 34 - Después de moverse hacia [125, 428]
#    125
#    428
# 35 - Después de moverse hacia [125, 429]
#    125
#    429
# 36 - Después de moverse hacia [125, 430]
#    125
#    430
# 37 - Después de moverse hacia [125, 431]
#    125
#    431
# 38 - Después de moverse hacia [124, 432]
#    124
#    432
# 39 - Después de moverse hacia [124, 433]
#    124
#    433
# 40 - Después de moverse hacia [124, 434]
#    124
#    434
# 41 - Después de moverse hacia [124, 435]
#    124
#    435
# 42 - Después de moverse hacia [125, 436]
#    125
#    436
# 43 - Después de moverse hacia [124, 437]
#    124
#    437
# 44 - Después de moverse hacia [125, 438]
#    125
#    438
# 45 - Después de moverse hacia [125, 439]
#    125
#    439
# 46 - Después de moverse hacia [126, 440]
#    126
#    440
# 47 - Después de moverse hacia [126, 441]
#    126
#    441
# 48 - Después de moverse hacia [126, 442]
#    126
#    442
# 49 - Después de moverse hacia [126, 443]
#    126
#    443
# 50 - Después de moverse hacia [125, 443]
#    125
#    443
# 51 - Después de moverse hacia [124, 444]
#    124
#    444
# 52 - Después de moverse hacia [123, 443]
#    123
#    443
# 53 - Después de moverse hacia [122, 443]
#    122
#    443
# 54 - Después de moverse hacia [121, 443]
#    121
#    443
# 55 - Después de moverse hacia [120, 442]
#    120
#    442
# 56 - Después de moverse hacia [119, 442]
#    119
#    442
# 57 - Después de moverse hacia [118, 441]
#    118
#    441
# 58 - Después de moverse hacia [117, 441]
#    117
#    441
# 59 - Después de moverse hacia [116, 441]
#    116
#    441
# 60 - Después de moverse hacia [115, 441]
#    115
#    441
# 61 - Después de moverse hacia [114, 441]
#    114
#    441
# 62 - Después de moverse hacia [113, 440]
#    113
#    440
# 63 - Después de moverse hacia [112, 439]
#    112
#    439
# 64 - Después de moverse hacia [111, 439]
#    111
#    439
# 65 - Después de moverse hacia [110, 439]
#    110
#    439
# 66 - Después de moverse hacia [109, 438]
#    109
#    438
# 67 - Después de moverse hacia [108, 437]
#    108
#    437
# 68 - Después de moverse hacia [108, 438]
#    108
#    438
# 69 - Después de moverse hacia [108, 439]
# ¡Meta lograda con costo = 794.7655999999993 !
#    108
#    439
# Stats:
# {'max_fringe_size': 2035, 'visited_nodes': 81106, 'iterations': 81106}

# %%
#---------------------------------------------------------------------------------------------------------------
#    PSA del robot explorador de Marte
#---------------------------------------------------------------------------------------------------------------

from simpleai.search import SearchProblem, depth_first, breadth_first, uniform_cost, greedy, astar
from simpleai.search.viewers import BaseViewer, ConsoleViewer, WebViewer
import numpy as np

#---------------------------------------------------------------------------------------------------------------
#   Definición del problema
#---------------------------------------------------------------------------------------------------------------

class Marte(SearchProblem):

    """
        Clase que es usada para definir el problema del robot explorador de Marte. Cada estado se representa
        por una coordenada.
    """

    def __init__(self):

        self.mapa = np.load('/content/mars_map.npy') # se crea el mapa de Marte
        self.nr, self.nc = self.mapa.shape # # se saca el tamaño del mapa
        self.x=3800 # x inicial
        self.y=16500 # y inicial
        self.r=self.nr-round(self.y/10.0174) # row escalado
        self.c=round(self.x/10.0174) # column escalado
        self.dif=0.25 # altura que puede bajar o subir

        initial_state = (self.r,self.c) # Estado (coordenada) en el que comienza el robot


        # Llama al constructor de su superclase SearchProblem.
        SearchProblem.__init__(self, initial_state)

        # Define el estado meta = que el robot termine en las coordenadas (2400, 16000) ya escalado como en el mapa
        self.goal_state = (self.nr-round(16900/10.0174),round(3900/10.0174))

    def actions(self, state):
        """
            Este método regresa una lista con las acciones posibles que pueden ser ejecutadas de
            acuerdo con el estado especificado.

            state: todas las coordenadas del mapa

            state[0] = row
            state[1] = column
        """

        acciones=[]
        #Movimiento hacia delante (respecto a la matriz)
        if self.mapa[state[0]][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]+1])<self.dif:
          a1=[state[0],state[1]+1]
          acciones.append(a1)
        #Movimiento hacia atras (respecto a la matriz)
        if self.mapa[state[0]][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]-1])<self.dif:
          a2=[state[0],state[1]-1]
          acciones.append(a2)
        #Movimiento hacia la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]])<self.dif:
          a3=[state[0]+1,state[1]]
          acciones.append(a3)
        #Movimiento hacia la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]])<self.dif:
          a4=[state[0]-1,state[1]]
          acciones.append(a4)
        #Movimiento en diagonal hacia delante y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]+1])<self.dif:
          a5=[state[0]+1,state[1]+1]
          acciones.append(a5)
        #Movimiento en diagonal hacia delante y la izquierda
        if self.mapa[state[0]-1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]+1])<self.dif:
          a6=[state[0]-1,state[1]+1]
          acciones.append(a6)
        #Movimiento en diagonal hacia atras y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]-1])<self.dif:
          a7=[state[0]+1,state[1]-1]
          acciones.append(a7)
        #Movimiento en diagonal hacia atras y la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]-1])<self.dif:
          a8=[state[0]-1,state[1]-1]
          acciones.append(a8)


        return acciones

    def result(self, state, action):
        """
            Este método regresa el nuevo estado obtenido despues de ejecutar la acción.

            state: el estado (coordenada) que se va a modificar
            action: movimiento que se hará en state (estado/coordenada)
        """
        return tuple([action[0],action[1]])

    def is_goal(self, state):
        """
            This method evaluates whether the specified state is the goal state.

            state: The state to be tested.
        """
        return state == self.goal_state

    def cost(self, state, action, state2):
        """
            Este método recibe dos estados y una acción, y regresa el costo de
            aplicar la acción del primer estado al segundo.

            state: Primer estado
            action: Acción usada para generar el segundo estado
            state2: Estado obtenido después de la acción
        """
        if abs(state2[0]-state[0]) == 1 and abs(state2[1]-state[1]) == 1:
          #moverse cada vez en diagonal tiene costo de 14.16
          return 14.16
        else:
          # moverse de otra forma tiene costo de 10.174
          return 10.0174


    def heuristic(self, state):
        """
            Este método regresa un estimado de la distancia desde el estado a la meta.

            state: Estado a ser evaluado

            La heurística es la distancia que le queda de llegar de donde está a la meta
        """
        distancia_diagonal=np.sqrt(((state[0]-self.goal_state[0])**2)+((state[1]-self.goal_state[1])**2))

        return distancia_diagonal


# Despliega los resultados
def display(result):
    if result is not None:
        for i, (action, state) in enumerate(result.path()):
            if action == None:
                print('Configuración inicial')
            elif i == len(result.path()) - 1:
                print(i,'- Después de moverse hacia', action)
                print('¡Meta lograda con costo =', result.cost,'!')
            else:
                print(i,'- Después de moverse hacia', action)

            for i in state:
              print('  ', i)
    else:
        print('No se puede resolver')

#---------------------------------------------------------------------------------------------------------------
#   Fin del archivo
#---------------------------------------------------------------------------------------------------------------

# %%
# Crea un PSA y lo resuelve con la búsqueda a*
result = astar(Marte(), graph_search=True, viewer=my_viewer)
print()
print('>> Ruta hacia el punto destino')
display(result)
if my_viewer!=None:
    print('Stats:')
    print(my_viewer.stats)
print('\n\n')
# Out:
# >> Ruta hacia el punto destino
# Configuración inicial
#    168
#    379
# 1 - Después de moverse hacia [167, 380]
#    167
#    380
# 2 - Después de moverse hacia [166, 381]
#    166
#    381
# 3 - Después de moverse hacia [166, 382]
#    166
#    382
# 4 - Después de moverse hacia [166, 383]
#    166
#    383
# 5 - Después de moverse hacia [165, 384]
#    165
#    384
# 6 - Después de moverse hacia [164, 384]
#    164
#    384
# 7 - Después de moverse hacia [163, 384]
#    163
#    384
# 8 - Después de moverse hacia [162, 384]
#    162
#    384
# 9 - Después de moverse hacia [161, 383]
#    161
#    383
# 10 - Después de moverse hacia [160, 384]
#    160
#    384
# 11 - Después de moverse hacia [159, 383]
#    159
#    383
# 12 - Después de moverse hacia [158, 383]
#    158
#    383
# 13 - Después de moverse hacia [157, 384]
#    157
#    384
# 14 - Después de moverse hacia [156, 384]
#    156
#    384
# 15 - Después de moverse hacia [155, 385]
#    155
#    385
# 16 - Después de moverse hacia [154, 385]
#    154
#    385
# 17 - Después de moverse hacia [153, 385]
#    153
#    385
# 18 - Después de moverse hacia [153, 386]
#    153
#    386
# 19 - Después de moverse hacia [152, 385]
#    152
#    385
# 20 - Después de moverse hacia [151, 386]
#    151
#    386
# 21 - Después de moverse hacia [150, 386]
#    150
#    386
# 22 - Después de moverse hacia [149, 386]
#    149
#    386
# 23 - Después de moverse hacia [148, 386]
#    148
#    386
# 24 - Después de moverse hacia [147, 386]
#    147
#    386
# 25 - Después de moverse hacia [146, 387]
#    146
#    387
# 26 - Después de moverse hacia [145, 388]
#    145
#    388
# 27 - Después de moverse hacia [144, 387]
#    144
#    387
# 28 - Después de moverse hacia [143, 387]
#    143
#    387
# 29 - Después de moverse hacia [142, 387]
#    142
#    387
# 30 - Después de moverse hacia [141, 388]
#    141
#    388
# 31 - Después de moverse hacia [140, 388]
#    140
#    388
# 32 - Después de moverse hacia [139, 389]
#    139
#    389
# 33 - Después de moverse hacia [138, 389]
#    138
#    389
# 34 - Después de moverse hacia [137, 390]
#    137
#    390
# 35 - Después de moverse hacia [136, 390]
#    136
#    390
# 36 - Después de moverse hacia [135, 391]
#    135
#    391
# 37 - Después de moverse hacia [134, 390]
#    134
#    390
# 38 - Después de moverse hacia [133, 390]
#    133
#    390
# 39 - Después de moverse hacia [132, 390]
#    132
#    390
# 40 - Después de moverse hacia [131, 390]
#    131
#    390
# 41 - Después de moverse hacia [130, 390]
#    130
#    390
# 42 - Después de moverse hacia [129, 390]
#    129
#    390
# 43 - Después de moverse hacia [128, 389]
# ¡Meta lograda con costo = 509.45760000000035 !
#    128
#    389
# Stats:
# {'max_fringe_size': 2035, 'visited_nodes': 108645, 'iterations': 108645}

# %% [markdown]
# # Ruta mediana

# %%
#---------------------------------------------------------------------------------------------------------------
#    PSA del robot explorador de Marte
#---------------------------------------------------------------------------------------------------------------

from simpleai.search import SearchProblem, depth_first, breadth_first, uniform_cost, greedy, astar
from simpleai.search.viewers import BaseViewer, ConsoleViewer, WebViewer
import numpy as np

#---------------------------------------------------------------------------------------------------------------
#   Definición del problema
#---------------------------------------------------------------------------------------------------------------

class Marte(SearchProblem):

    """
        Clase que es usada para definir el problema del robot explorador de Marte. Cada estado se representa
        por una coordenada.
    """

    def __init__(self):

        self.mapa = np.load('/content/mars_map.npy') # se crea el mapa de Marte
        self.nr, self.nc = self.mapa.shape # # se saca el tamaño del mapa
        self.x=3800 # x inicial
        self.y=15000 # y inicial
        self.r=self.nr-round(self.y/10.0174) # row escalado
        self.c=round(self.x/10.0174) # column escalado
        self.dif=0.25 # altura que puede bajar o subir

        initial_state = (self.r,self.c) # Estado (coordenada) en el que comienza el robot


        # Llama al constructor de su superclase SearchProblem.
        SearchProblem.__init__(self, initial_state)

        # Define el estado meta = que el robot termine en las coordenadas (2400, 16000) ya escalado como en el mapa
        self.goal_state = (self.nr-round(16500/10.0174),round(6000/10.0174))

    def actions(self, state):
        """
            Este método regresa una lista con las acciones posibles que pueden ser ejecutadas de
            acuerdo con el estado especificado.

            state: todas las coordenadas del mapa

            state[0] = row
            state[1] = column
        """

        acciones=[]
        #Movimiento hacia delante (respecto a la matriz)
        if self.mapa[state[0]][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]+1])<self.dif:
          a1=[state[0],state[1]+1]
          acciones.append(a1)
        #Movimiento hacia atras (respecto a la matriz)
        if self.mapa[state[0]][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]-1])<self.dif:
          a2=[state[0],state[1]-1]
          acciones.append(a2)
        #Movimiento hacia la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]])<self.dif:
          a3=[state[0]+1,state[1]]
          acciones.append(a3)
        #Movimiento hacia la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]])<self.dif:
          a4=[state[0]-1,state[1]]
          acciones.append(a4)
        #Movimiento en diagonal hacia delante y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]+1])<self.dif:
          a5=[state[0]+1,state[1]+1]
          acciones.append(a5)
        #Movimiento en diagonal hacia delante y la izquierda
        if self.mapa[state[0]-1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]+1])<self.dif:
          a6=[state[0]-1,state[1]+1]
          acciones.append(a6)
        #Movimiento en diagonal hacia atras y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]-1])<self.dif:
          a7=[state[0]+1,state[1]-1]
          acciones.append(a7)
        #Movimiento en diagonal hacia atras y la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]-1])<self.dif:
          a8=[state[0]-1,state[1]-1]
          acciones.append(a8)


        return acciones

    def result(self, state, action):
        """
            Este método regresa el nuevo estado obtenido despues de ejecutar la acción.

            state: el estado (coordenada) que se va a modificar
            action: movimiento que se hará en state (estado/coordenada)
        """
        return tuple([action[0],action[1]])

    def is_goal(self, state):
        """
            This method evaluates whether the specified state is the goal state.

            state: The state to be tested.
        """
        return state == self.goal_state

    def cost(self, state, action, state2):
        """
            Este método recibe dos estados y una acción, y regresa el costo de
            aplicar la acción del primer estado al segundo.

            state: Primer estado
            action: Acción usada para generar el segundo estado
            state2: Estado obtenido después de la acción
        """
        if abs(state2[0]-state[0]) == 1 and abs(state2[1]-state[1]) == 1:
          #moverse cada vez en diagonal tiene costo de 14.16
          return 14.16
        else:
          # moverse de otra forma tiene costo de 10.174
          return 10.0174


    def heuristic(self, state):
        """
            Este método regresa un estimado de la distancia desde el estado a la meta.

            state: Estado a ser evaluado

            La heurística es la distancia que le queda de llegar de donde está a la meta
        """
        distancia_diagonal=np.sqrt(((state[0]-self.goal_state[0])**2)+((state[1]-self.goal_state[1])**2))

        return distancia_diagonal


# Despliega los resultados
def display(result):
    if result is not None:
        for i, (action, state) in enumerate(result.path()):
            if action == None:
                print('Configuración inicial')
            elif i == len(result.path()) - 1:
                print(i,'- Después de moverse hacia', action)
                print('¡Meta lograda con costo =', result.cost,'!')
            else:
                print(i,'- Después de moverse hacia', action)

            for i in state:
              print('  ', i)
    else:
        print('No se puede resolver')

#---------------------------------------------------------------------------------------------------------------
#   Fin del archivo
#---------------------------------------------------------------------------------------------------------------

# %%
# Crea un PSA y lo resuelve con la búsqueda a*
result = astar(Marte(), graph_search=True, viewer=my_viewer)
print()
print('>> Ruta hacia el punto destino')
display(result)
if my_viewer!=None:
    print('Stats:')
    print(my_viewer.stats)
print('\n\n')
# Out:
# >> Ruta hacia el punto destino
# No se puede resolver
# Stats:
# {'max_fringe_size': 2035, 'visited_nodes': 640052, 'iterations': 640052}

# %%
#---------------------------------------------------------------------------------------------------------------
#    PSA del robot explorador de Marte
#---------------------------------------------------------------------------------------------------------------

from simpleai.search import SearchProblem, depth_first, breadth_first, uniform_cost, greedy, astar
from simpleai.search.viewers import BaseViewer, ConsoleViewer, WebViewer
import numpy as np

#---------------------------------------------------------------------------------------------------------------
#   Definición del problema
#---------------------------------------------------------------------------------------------------------------

class Marte(SearchProblem):

    """
        Clase que es usada para definir el problema del robot explorador de Marte. Cada estado se representa
        por una coordenada.
    """

    def __init__(self):

        self.mapa = np.load('/content/mars_map.npy') # se crea el mapa de Marte
        self.nr, self.nc = self.mapa.shape # # se saca el tamaño del mapa
        self.x=5000 # x inicial
        self.y=13000 # y inicial
        self.r=self.nr-round(self.y/10.0174) # row escalado
        self.c=round(self.x/10.0174) # column escalado
        self.dif=0.25 # altura que puede bajar o subir

        initial_state = (self.r,self.c) # Estado (coordenada) en el que comienza el robot


        # Llama al constructor de su superclase SearchProblem.
        SearchProblem.__init__(self, initial_state)

        # Define el estado meta = que el robot termine en las coordenadas (2400, 16000) ya escalado como en el mapa
        self.goal_state = (self.nr-round(14500/10.0174),round(6000/10.0174))

    def actions(self, state):
        """
            Este método regresa una lista con las acciones posibles que pueden ser ejecutadas de
            acuerdo con el estado especificado.

            state: todas las coordenadas del mapa

            state[0] = row
            state[1] = column
        """

        acciones=[]
        #Movimiento hacia delante (respecto a la matriz)
        if self.mapa[state[0]][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]+1])<self.dif:
          a1=[state[0],state[1]+1]
          acciones.append(a1)
        #Movimiento hacia atras (respecto a la matriz)
        if self.mapa[state[0]][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]-1])<self.dif:
          a2=[state[0],state[1]-1]
          acciones.append(a2)
        #Movimiento hacia la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]])<self.dif:
          a3=[state[0]+1,state[1]]
          acciones.append(a3)
        #Movimiento hacia la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]])<self.dif:
          a4=[state[0]-1,state[1]]
          acciones.append(a4)
        #Movimiento en diagonal hacia delante y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]+1])<self.dif:
          a5=[state[0]+1,state[1]+1]
          acciones.append(a5)
        #Movimiento en diagonal hacia delante y la izquierda
        if self.mapa[state[0]-1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]+1])<self.dif:
          a6=[state[0]-1,state[1]+1]
          acciones.append(a6)
        #Movimiento en diagonal hacia atras y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]-1])<self.dif:
          a7=[state[0]+1,state[1]-1]
          acciones.append(a7)
        #Movimiento en diagonal hacia atras y la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]-1])<self.dif:
          a8=[state[0]-1,state[1]-1]
          acciones.append(a8)


        return acciones

    def result(self, state, action):
        """
            Este método regresa el nuevo estado obtenido despues de ejecutar la acción.

            state: el estado (coordenada) que se va a modificar
            action: movimiento que se hará en state (estado/coordenada)
        """
        return tuple([action[0],action[1]])

    def is_goal(self, state):
        """
            This method evaluates whether the specified state is the goal state.

            state: The state to be tested.
        """
        return state == self.goal_state

    def cost(self, state, action, state2):
        """
            Este método recibe dos estados y una acción, y regresa el costo de
            aplicar la acción del primer estado al segundo.

            state: Primer estado
            action: Acción usada para generar el segundo estado
            state2: Estado obtenido después de la acción
        """
        if abs(state2[0]-state[0]) == 1 and abs(state2[1]-state[1]) == 1:
          #moverse cada vez en diagonal tiene costo de 14.16
          return 14.16
        else:
          # moverse de otra forma tiene costo de 10.174
          return 10.0174


    def heuristic(self, state):
        """
            Este método regresa un estimado de la distancia desde el estado a la meta.

            state: Estado a ser evaluado

            La heurística es la distancia que le queda de llegar de donde está a la meta
        """
        distancia_diagonal=np.sqrt(((state[0]-self.goal_state[0])**2)+((state[1]-self.goal_state[1])**2))

        return distancia_diagonal


# Despliega los resultados
def display(result):
    if result is not None:
        for i, (action, state) in enumerate(result.path()):
            if action == None:
                print('Configuración inicial')
            elif i == len(result.path()) - 1:
                print(i,'- Después de moverse hacia', action)
                print('¡Meta lograda con costo =', result.cost,'!')
            else:
                print(i,'- Después de moverse hacia', action)

            for i in state:
              print('  ', i)
    else:
        print('No se puede resolver')

#---------------------------------------------------------------------------------------------------------------
#   Fin del archivo
#---------------------------------------------------------------------------------------------------------------

# %%
# Crea un PSA y lo resuelve con la búsqueda a*
result = astar(Marte(), graph_search=True, viewer=my_viewer)
print()
print('>> Ruta hacia el punto destino')
display(result)
if my_viewer!=None:
    print('Stats:')
    print(my_viewer.stats)
print('\n\n')
# Out:
# >> Ruta hacia el punto destino
# No se puede resolver
# Stats:
# {'max_fringe_size': 2035, 'visited_nodes': 72262, 'iterations': 72262}

# %% [markdown]
# # Ruta de mas de 10,000

# %%
#---------------------------------------------------------------------------------------------------------------
#    PSA del robot explorador de Marte
#---------------------------------------------------------------------------------------------------------------

from simpleai.search import SearchProblem, depth_first, breadth_first, uniform_cost, greedy, astar
from simpleai.search.viewers import BaseViewer, ConsoleViewer, WebViewer
import numpy as np

#---------------------------------------------------------------------------------------------------------------
#   Definición del problema
#---------------------------------------------------------------------------------------------------------------

class Marte(SearchProblem):

    """
        Clase que es usada para definir el problema del robot explorador de Marte. Cada estado se representa
        por una coordenada.
    """

    def __init__(self):

        self.mapa = np.load('/content/mars_map.npy') # se crea el mapa de Marte
        self.nr, self.nc = self.mapa.shape # # se saca el tamaño del mapa
        self.x=5000 # x inicial
        self.y=16000 # y inicial
        self.r=self.nr-round(self.y/10.0174) # row escalado
        self.c=round(self.x/10.0174) # column escalado
        self.dif=0.25 # altura que puede bajar o subir

        initial_state = (self.r,self.c) # Estado (coordenada) en el que comienza el robot


        # Llama al constructor de su superclase SearchProblem.
        SearchProblem.__init__(self, initial_state)

        # Define el estado meta = que el robot termine en las coordenadas (2400, 16000) ya escalado como en el mapa
        self.goal_state = (self.nr-round(1400/10.0174),round(6000/10.0174))

    def actions(self, state):
        """
            Este método regresa una lista con las acciones posibles que pueden ser ejecutadas de
            acuerdo con el estado especificado.

            state: todas las coordenadas del mapa

            state[0] = row
            state[1] = column
        """

        acciones=[]
        #Movimiento hacia delante (respecto a la matriz)
        if self.mapa[state[0]][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]+1])<self.dif:
          a1=[state[0],state[1]+1]
          acciones.append(a1)
        #Movimiento hacia atras (respecto a la matriz)
        if self.mapa[state[0]][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]][state[1]-1])<self.dif:
          a2=[state[0],state[1]-1]
          acciones.append(a2)
        #Movimiento hacia la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]])<self.dif:
          a3=[state[0]+1,state[1]]
          acciones.append(a3)
        #Movimiento hacia la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]])<self.dif:
          a4=[state[0]-1,state[1]]
          acciones.append(a4)
        #Movimiento en diagonal hacia delante y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]+1])<self.dif:
          a5=[state[0]+1,state[1]+1]
          acciones.append(a5)
        #Movimiento en diagonal hacia delante y la izquierda
        if self.mapa[state[0]-1][state[1]+1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]+1])<self.dif:
          a6=[state[0]-1,state[1]+1]
          acciones.append(a6)
        #Movimiento en diagonal hacia atras y la derecha (respecto a la matriz)
        if self.mapa[state[0]+1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]+1][state[1]-1])<self.dif:
          a7=[state[0]+1,state[1]-1]
          acciones.append(a7)
        #Movimiento en diagonal hacia atras y la izquierda (respecto a la matriz)
        if self.mapa[state[0]-1][state[1]-1] !=-1 and abs(self.mapa[state[0]][state[1]]-self.mapa[state[0]-1][state[1]-1])<self.dif:
          a8=[state[0]-1,state[1]-1]
          acciones.append(a8)


        return acciones

    def result(self, state, action):
        """
            Este método regresa el nuevo estado obtenido despues de ejecutar la acción.

            state: el estado (coordenada) que se va a modificar
            action: movimiento que se hará en state (estado/coordenada)
        """
        return tuple([action[0],action[1]])

    def is_goal(self, state):
        """
            This method evaluates whether the specified state is the goal state.

            state: The state to be tested.
        """
        return state == self.goal_state

    def cost(self, state, action, state2):
        """
            Este método recibe dos estados y una acción, y regresa el costo de
            aplicar la acción del primer estado al segundo.

            state: Primer estado
            action: Acción usada para generar el segundo estado
            state2: Estado obtenido después de la acción
        """
        if abs(state2[0]-state[0]) == 1 and abs(state2[1]-state[1]) == 1:
          #moverse cada vez en diagonal tiene costo de 14.16
          return 14.16
        else:
          # moverse de otra forma tiene costo de 10.174
          return 10.0174


    def heuristic(self, state):
        """
            Este método regresa un estimado de la distancia desde el estado a la meta.

            state: Estado a ser evaluado

            La heurística es la distancia que le queda de llegar de donde está a la meta
        """
        distancia_diagonal=np.sqrt(((state[0]-self.goal_state[0])**2)+((state[1]-self.goal_state[1])**2))

        return distancia_diagonal


# Despliega los resultados
def display(result):
    if result is not None:
        for i, (action, state) in enumerate(result.path()):
            if action == None:
                print('Configuración inicial')
            elif i == len(result.path()) - 1:
                print(i,'- Después de moverse hacia', action)
                print('¡Meta lograda con costo =', result.cost,'!')
            else:
                print(i,'- Después de moverse hacia', action)

            for i in state:
              print('  ', i)
    else:
        print('No se puede resolver')

#---------------------------------------------------------------------------------------------------------------
#   Fin del archivo
#---------------------------------------------------------------------------------------------------------------

# %%
# Crea un PSA y lo resuelve con la búsqueda a*
result = astar(Marte(), graph_search=True, viewer=my_viewer)
print()
print('>> Ruta hacia el punto destino')
display(result)
if my_viewer!=None:
    print('Stats:')
    print(my_viewer.stats)
print('\n\n')
# Out:
# >> Ruta hacia el punto destino
# No se puede resolver
# Stats:
# {'max_fringe_size': 2035, 'visited_nodes': 72268, 'iterations': 72268}
